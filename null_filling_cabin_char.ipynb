# %%
import pandas as pd
import os
import torch
import numpy as np
import random
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
# fix seed for reproducibility
SEED = 0
torch.manual_seed(SEED)
random.seed(SEED)
np.random.seed(SEED)

# %%
# Preprocess and clean data
def clean_df(df, test=False):
    
    # Drop PassengerId and Name
    df.drop('PassengerId', axis='columns', inplace=True)
    df.drop('Name', axis='columns', inplace=True)

    # Cabin dictionary, char to int
    cabin_dict = {
    'A':0,
    'B':1,
    'C':2,
    'D':3,
    'E':4,
    'F':5,
    'G':6,
    'T':7
    }

    # Change cabin value just to char ids, ex.  B36 -> 1
    # Column for training data
    if not test:
        # Iterate by rows
        for c_i, cabin in enumerate(df['Cabin']):
            # Change only value with str datatype
            if not isinstance(cabin,str):
                continue
            # Iterate by row value
            for n_i ,char in enumerate(cabin):
                # Start iterating from last to first char
                index = -1 - n_i
                # If given char in cabin dictionary
                if cabin[index] in cabin_dict.keys():
                    # Change given row value to char id
                    df['Cabin'][c_i] = cabin_dict[cabin[index]]
                    break


    # Change ticket value just to numbers
    # Iterate by rows
    for t_i, ticket in enumerate(df['Ticket']):
        # If ticket value == LINE change to 0
        if ticket == 'LINE':
            df.loc[t_i, 'Ticket'] = 0
        # Iterate by row value
        for c_i ,char in enumerate(ticket):
            # Start iterating from last to first char
            index = -1 - c_i
            # If whitespace found 
            if ticket[index] == ' ':
                # Change value to numbers after whitespace
                df.loc[t_i, 'Ticket'] = df['Ticket'][t_i][index+1:]   
                break
        continue

        # Reset dataframe indexing
    df.reset_index()

    # Create column for each embarked
    df['Embarked_C'] = [1 if embarked == 'C' else 0 for embarked in df['Embarked']]
    df['Embarked_Q'] = [1 if embarked == 'Q' else 0 for embarked in df['Embarked']]
    df['Embarked_S'] = [1 if embarked == 'S' else 0 for embarked in df['Embarked']]
    
    # delete old embarked column
    df.drop('Embarked', axis='columns', inplace=True)

    # Sex dictionary, str to int
    sex_dict = {
        'male':0,
        'female':1
    }

    # Replace values in dataframe with dictionary
    df.replace({'Sex':sex_dict}, inplace=True)

    # Fill na values with mean
    df.fillna(
                {
                'Age': df['Age'].mean(),
                'Fare': df['Fare'].mean(),
                },
                inplace=True
                ) 

    # If training data save temporary column
    if not test:
        df_y = df['Cabin']
        df_y= (df_y).astype(float)
        # drop Cabin from dataframe
        df.drop('Cabin', axis='columns', inplace=True)

    # Drop rows with empty Ticket value
    df = df[df.Ticket != '']
    # Change Ticket datatype
    df['Ticket'] = (df['Ticket']).astype(float)

    # Change dataframe values range from 0 to 1
    df=(df-df.min())/(df.max()-df.min())

    # If training join Cabin column
    if not test:
        df = df.join(df_y)

    return df

# %%
# load data
DATA_PATH = 'data'
train_data_path = os.path.join(DATA_PATH,'test.csv')
train_df = pd.read_csv(train_data_path, sep=',')

# extract null values to predict
df_to_predict = train_df[train_df.isnull().any(axis=1)]
df_to_predict.reset_index(inplace=True)

# save list of row indexes for prediction
null_indexes = df_to_predict['index']
# drop index and Cabin column
df_to_predict.drop('index', axis='columns', inplace=True)
df_to_predict.drop('Cabin', axis='columns', inplace=True)
# preprocess data for prediction
df_to_predict = clean_df(df_to_predict, test=True)
# drop null values
train_df = train_df.dropna()
train_df.reset_index(inplace=True)
# drop index
train_df.drop('index', axis='columns', inplace=True)
# preprocess training data
train_df = clean_df(train_df)
# change df to np
train_set = train_df.to_numpy()
data_to_predict = df_to_predict.to_numpy()

#split data
print(len(train_set))
train_set, val_set = torch.utils.data.random_split(train_set, [70, 17])

# change np to array | to avoid slice errors
train_set = np.array(train_set)
val_set = np.array(val_set)
X_train,y_train = train_set[:,:-1],train_set[:,-1]
X_val,y_val = val_set[:,:-1],val_set[:,-1]
# Out:
# 87

# %%
# create model
clf = SVC(random_state=0)

# train model
clf.fit(X_train, y_train)

# score model
clf.score(X_val, y_val)

# cross validation
scores = cross_val_score(clf, X_train, y_train, cv = 4)
scores
# Out:
# array([0.38888889, 0.38888889, 0.41176471, 0.35294118])

# %%
# cabin dictionary
cabin_dict = {
'A':0,
'B':1,
'C':2,
'D':3,
'E':4,
'F':5,
'G':6,
'T':7
}

# create list for predictions
filled_null_cabin_chars = []
# predict cabin letter
preds = clf.predict(data_to_predict)
# Create a list of PassengerId: prediction
for index,pred in zip(null_indexes,preds):
    pred = int(pred)
    cabin_number = list(cabin_dict.keys())[list(cabin_dict.values()).index(pred)]
    filled_null_cabin_chars.append({
        'PassengerId':index,
        'value':cabin_number
    })
filled_null_cabin_chars
# Out:
# [{'PassengerId': 0, 'value': 'C'},
#  {'PassengerId': 1, 'value': 'F'},
#  {'PassengerId': 2, 'value': 'C'},
#  {'PassengerId': 3, 'value': 'F'},
#  {'PassengerId': 4, 'value': 'F'},
#  {'PassengerId': 5, 'value': 'F'},
#  {'PassengerId': 6, 'value': 'C'},
#  {'PassengerId': 7, 'value': 'B'},
#  {'PassengerId': 8, 'value': 'C'},
#  {'PassengerId': 9, 'value': 'F'},
#  {'PassengerId': 10, 'value': 'F'},
#  {'PassengerId': 11, 'value': 'C'},
#  {'PassengerId': 13, 'value': 'C'},
#  {'PassengerId': 15, 'value': 'C'},
#  {'PassengerId': 16, 'value': 'C'},
#  {'PassengerId': 17, 'value': 'C'},
#  {'PassengerId': 18, 'value': 'F'},
#  {'PassengerId': 19, 'value': 'C'},
#  {'PassengerId': 20, 'value': 'C'},
#  {'PassengerId': 21, 'value': 'F'},
#  {'PassengerId': 22, 'value': 'C'},
#  {'PassengerId': 23, 'value': 'C'},
#  {'PassengerId': 25, 'value': 'F'},
#  {'PassengerId': 27, 'value': 'C'},
#  {'PassengerId': 29, 'value': 'C'},
#  {'PassengerId': 30, 'value': 'C'},
#  {'PassengerId': 31, 'value': 'B'},
#  {'PassengerId': 32, 'value': 'F'},
#  {'PassengerId': 33, 'value': 'F'},
#  {'PassengerId': 35, 'value': 'C'},
#  {'PassengerId': 36, 'value': 'F'},
#  {'PassengerId': 37, 'value': 'F'},
#  {'PassengerId': 38, 'value': 'F'},
#  {'PassengerId': 39, 'value': 'F'},
#  {'PassengerId': 40, 'value': 'C'},
#  {'PassengerId': 41, 'value': 'B'},
#  {'PassengerId': 42, 'value': 'F'},
#  {'PassengerId': 43, 'value': 'C'},
#  {'PassengerId': 45, 'value': 'F'},
#  {'PassengerId': 47, 'value': 'C'},
#  {'PassengerId': 49, 'value': 'F'},
#  {'PassengerId': 51, 'value': 'C'},
#  {'PassengerId': 52, 'value': 'C'},
#  {'PassengerId': 54, 'value': 'C'},
#  {'PassengerId': 55, 'value': 'C'},
#  {'PassengerId': 56, 'value': 'F'},
#  {'PassengerId': 58, 'value': 'F'},
#  {'PassengerId': 60, 'value': 'F'},
#  {'PassengerId': 61, 'value': 'B'},
#  {'PassengerId': 62, 'value': 'F'},
#  {'PassengerId': 63, 'value': 'C'},
#  {'PassengerId': 65, 'value': 'C'},
#  {'PassengerId': 66, 'value': 'C'},
#  {'PassengerId': 67, 'value': 'C'},
#  {'PassengerId': 70, 'value': 'C'},
#  {'PassengerId': 71, 'value': 'F'},
#  {'PassengerId': 72, 'value': 'F'},
#  {'PassengerId': 76, 'value': 'F'},
#  {'PassengerId': 78, 'value': 'B'},
#  {'PassengerId': 79, 'value': 'C'},
#  {'PassengerId': 80, 'value': 'C'},
#  {'PassengerId': 82, 'value': 'C'},
#  {'PassengerId': 83, 'value': 'F'},
#  {'PassengerId': 84, 'value': 'C'},
#  {'PassengerId': 85, 'value': 'C'},
#  {'PassengerId': 86, 'value': 'C'},
#  {'PassengerId': 87, 'value': 'F'},
#  {'PassengerId': 88, 'value': 'C'},
#  {'PassengerId': 89, 'value': 'B'},
#  {'PassengerId': 90, 'value': 'F'},
#  {'PassengerId': 91, 'value': 'F'},
#  {'PassengerId': 93, 'value': 'F'},
#  {'PassengerId': 94, 'value': 'C'},
#  {'PassengerId': 95, 'value': 'F'},
#  {'PassengerId': 97, 'value': 'F'},
#  {'PassengerId': 98, 'value': 'F'},
#  {'PassengerId': 99, 'value': 'F'},
#  {'PassengerId': 101, 'value': 'B'},
#  {'PassengerId': 102, 'value': 'C'},
#  {'PassengerId': 103, 'value': 'F'},
#  {'PassengerId': 104, 'value': 'C'},
#  {'PassengerId': 105, 'value': 'F'},
#  {'PassengerId': 106, 'value': 'C'},
#  {'PassengerId': 107, 'value': 'C'},
#  {'PassengerId': 108, 'value': 'F'},
#  {'PassengerId': 110, 'value': 'C'},
#  {'PassengerId': 111, 'value': 'C'},
#  {'PassengerId': 113, 'value': 'C'},
#  {'PassengerId': 115, 'value': 'C'},
#  {'PassengerId': 116, 'value': 'C'},
#  {'PassengerId': 119, 'value': 'C'},
#  {'PassengerId': 120, 'value': 'C'},
#  {'PassengerId': 121, 'value': 'C'},
#  {'PassengerId': 123, 'value': 'F'},
#  {'PassengerId': 124, 'value': 'C'},
#  {'PassengerId': 125, 'value': 'F'},
#  {'PassengerId': 126, 'value': 'F'},
#  {'PassengerId': 127, 'value': 'C'},
#  {'PassengerId': 128, 'value': 'C'},
#  {'PassengerId': 129, 'value': 'F'},
#  {'PassengerId': 130, 'value': 'F'},
#  {'PassengerId': 132, 'value': 'F'},
#  {'PassengerId': 133, 'value': 'C'},
#  {'PassengerId': 134, 'value': 'F'},
#  {'PassengerId': 135, 'value': 'F'},
#  {'PassengerId': 136, 'value': 'C'},
#  {'PassengerId': 137, 'value': 'B'},
#  {'PassengerId': 138, 'value': 'F'},
#  {'PassengerId': 139, 'value': 'F'},
#  {'PassengerId': 140, 'value': 'F'},
#  {'PassengerId': 141, 'value': 'C'},
#  {'PassengerId': 143, 'value': 'B'},
#  {'PassengerId': 144, 'value': 'C'},
#  {'PassengerId': 145, 'value': 'F'},
#  {'PassengerId': 146, 'value': 'B'},
#  {'PassengerId': 147, 'value': 'F'},
#  {'PassengerId': 148, 'value': 'B'},
#  {'PassengerId': 149, 'value': 'B'},
#  {'PassengerId': 151, 'value': 'C'},
#  {'PassengerId': 152, 'value': 'B'},
#  {'PassengerId': 153, 'value': 'F'},
#  {'PassengerId': 154, 'value': 'F'},
#  {'PassengerId': 155, 'value': 'F'},
#  {'PassengerId': 157, 'value': 'F'},
#  {'PassengerId': 159, 'value': 'F'},
#  {'PassengerId': 160, 'value': 'C'},
#  {'PassengerId': 161, 'value': 'C'},
#  {'PassengerId': 162, 'value': 'F'},
#  {'PassengerId': 163, 'value': 'F'},
#  {'PassengerId': 164, 'value': 'C'},
#  {'PassengerId': 165, 'value': 'F'},
#  {'PassengerId': 167, 'value': 'F'},
#  {'PassengerId': 168, 'value': 'C'},
#  {'PassengerId': 169, 'value': 'F'},
#  {'PassengerId': 170, 'value': 'F'},
#  {'PassengerId': 171, 'value': 'C'},
#  {'PassengerId': 172, 'value': 'F'},
#  {'PassengerId': 173, 'value': 'C'},
#  {'PassengerId': 174, 'value': 'F'},
#  {'PassengerId': 175, 'value': 'F'},
#  {'PassengerId': 176, 'value': 'C'},
#  {'PassengerId': 180, 'value': 'B'},
#  {'PassengerId': 183, 'value': 'C'},
#  {'PassengerId': 185, 'value': 'C'},
#  {'PassengerId': 186, 'value': 'C'},
#  {'PassengerId': 187, 'value': 'F'},
#  {'PassengerId': 188, 'value': 'F'},
#  {'PassengerId': 189, 'value': 'C'},
#  {'PassengerId': 190, 'value': 'C'},
#  {'PassengerId': 191, 'value': 'B'},
#  {'PassengerId': 192, 'value': 'F'},
#  {'PassengerId': 193, 'value': 'C'},
#  {'PassengerId': 194, 'value': 'B'},
#  {'PassengerId': 195, 'value': 'F'},
#  {'PassengerId': 197, 'value': 'F'},
#  {'PassengerId': 198, 'value': 'B'},
#  {'PassengerId': 199, 'value': 'F'},
#  {'PassengerId': 200, 'value': 'C'},
#  {'PassengerId': 201, 'value': 'F'},
#  {'PassengerId': 203, 'value': 'F'},
#  {'PassengerId': 204, 'value': 'B'},
#  {'PassengerId': 205, 'value': 'C'},
#  {'PassengerId': 206, 'value': 'C'},
#  {'PassengerId': 207, 'value': 'B'},
#  {'PassengerId': 209, 'value': 'F'},
#  {'PassengerId': 210, 'value': 'F'},
#  {'PassengerId': 211, 'value': 'F'},
#  {'PassengerId': 212, 'value': 'C'},
#  {'PassengerId': 213, 'value': 'C'},
#  {'PassengerId': 214, 'value': 'F'},
#  {'PassengerId': 216, 'value': 'C'},
#  {'PassengerId': 217, 'value': 'C'},
#  {'PassengerId': 219, 'value': 'F'},
#  {'PassengerId': 220, 'value': 'C'},
#  {'PassengerId': 221, 'value': 'F'},
#  {'PassengerId': 223, 'value': 'F'},
#  {'PassengerId': 224, 'value': 'C'},
#  {'PassengerId': 225, 'value': 'C'},
#  {'PassengerId': 226, 'value': 'F'},
#  {'PassengerId': 227, 'value': 'C'},
#  {'PassengerId': 228, 'value': 'F'},
#  {'PassengerId': 229, 'value': 'B'},
#  {'PassengerId': 230, 'value': 'B'},
#  {'PassengerId': 231, 'value': 'C'},
#  {'PassengerId': 232, 'value': 'F'},
#  {'PassengerId': 233, 'value': 'C'},
#  {'PassengerId': 235, 'value': 'F'},
#  {'PassengerId': 237, 'value': 'C'},
#  {'PassengerId': 238, 'value': 'F'},
#  {'PassengerId': 240, 'value': 'C'},
#  {'PassengerId': 241, 'value': 'C'},
#  {'PassengerId': 243, 'value': 'F'},
#  {'PassengerId': 244, 'value': 'F'},
#  {'PassengerId': 246, 'value': 'C'},
#  {'PassengerId': 247, 'value': 'C'},
#  {'PassengerId': 248, 'value': 'C'},
#  {'PassengerId': 249, 'value': 'C'},
#  {'PassengerId': 250, 'value': 'F'},
#  {'PassengerId': 251, 'value': 'F'},
#  {'PassengerId': 253, 'value': 'F'},
#  {'PassengerId': 254, 'value': 'F'},
#  {'PassengerId': 255, 'value': 'F'},
#  {'PassengerId': 256, 'value': 'C'},
#  {'PassengerId': 257, 'value': 'F'},
#  {'PassengerId': 258, 'value': 'C'},
#  {'PassengerId': 259, 'value': 'F'},
#  {'PassengerId': 260, 'value': 'F'},
#  {'PassengerId': 261, 'value': 'F'},
#  {'PassengerId': 262, 'value': 'C'},
#  {'PassengerId': 263, 'value': 'F'},
#  {'PassengerId': 264, 'value': 'C'},
#  {'PassengerId': 265, 'value': 'F'},
#  {'PassengerId': 266, 'value': 'B'},
#  {'PassengerId': 267, 'value': 'F'},
#  {'PassengerId': 268, 'value': 'F'},
#  {'PassengerId': 269, 'value': 'F'},
#  {'PassengerId': 271, 'value': 'C'},
#  {'PassengerId': 273, 'value': 'C'},
#  {'PassengerId': 274, 'value': 'C'},
#  {'PassengerId': 275, 'value': 'F'},
#  {'PassengerId': 276, 'value': 'B'},
#  {'PassengerId': 277, 'value': 'C'},
#  {'PassengerId': 278, 'value': 'B'},
#  {'PassengerId': 279, 'value': 'B'},
#  {'PassengerId': 280, 'value': 'F'},
#  {'PassengerId': 281, 'value': 'F'},
#  {'PassengerId': 282, 'value': 'C'},
#  {'PassengerId': 283, 'value': 'C'},
#  {'PassengerId': 284, 'value': 'F'},
#  {'PassengerId': 285, 'value': 'F'},
#  {'PassengerId': 286, 'value': 'F'},
#  {'PassengerId': 288, 'value': 'C'},
#  {'PassengerId': 289, 'value': 'F'},
#  {'PassengerId': 290, 'value': 'B'},
#  {'PassengerId': 291, 'value': 'C'},
#  {'PassengerId': 292, 'value': 'C'},
#  {'PassengerId': 294, 'value': 'F'},
#  {'PassengerId': 295, 'value': 'F'},
#  {'PassengerId': 296, 'value': 'C'},
#  {'PassengerId': 297, 'value': 'C'},
#  {'PassengerId': 298, 'value': 'B'},
#  {'PassengerId': 299, 'value': 'F'},
#  {'PassengerId': 300, 'value': 'F'},
#  {'PassengerId': 301, 'value': 'C'},
#  {'PassengerId': 302, 'value': 'C'},
#  {'PassengerId': 303, 'value': 'F'},
#  {'PassengerId': 304, 'value': 'C'},
#  {'PassengerId': 307, 'value': 'F'},
#  {'PassengerId': 309, 'value': 'F'},
#  {'PassengerId': 310, 'value': 'F'},
#  {'PassengerId': 311, 'value': 'C'},
#  {'PassengerId': 312, 'value': 'F'},
#  {'PassengerId': 313, 'value': 'C'},
#  {'PassengerId': 315, 'value': 'C'},
#  {'PassengerId': 317, 'value': 'B'},
#  {'PassengerId': 318, 'value': 'F'},
#  {'PassengerId': 319, 'value': 'B'},
#  {'PassengerId': 320, 'value': 'F'},
#  {'PassengerId': 323, 'value': 'B'},
#  {'PassengerId': 324, 'value': 'C'},
#  {'PassengerId': 325, 'value': 'F'},
#  {'PassengerId': 327, 'value': 'C'},
#  {'PassengerId': 328, 'value': 'B'},
#  {'PassengerId': 329, 'value': 'B'},
#  {'PassengerId': 330, 'value': 'C'},
#  {'PassengerId': 332, 'value': 'C'},
#  {'PassengerId': 333, 'value': 'C'},
#  {'PassengerId': 334, 'value': 'F'},
#  {'PassengerId': 336, 'value': 'B'},
#  {'PassengerId': 337, 'value': 'C'},
#  {'PassengerId': 338, 'value': 'B'},
#  {'PassengerId': 339, 'value': 'C'},
#  {'PassengerId': 340, 'value': 'B'},
#  {'PassengerId': 341, 'value': 'F'},
#  {'PassengerId': 342, 'value': 'C'},
#  {'PassengerId': 344, 'value': 'F'},
#  {'PassengerId': 345, 'value': 'F'},
#  {'PassengerId': 346, 'value': 'B'},
#  {'PassengerId': 347, 'value': 'C'},
#  {'PassengerId': 348, 'value': 'B'},
#  {'PassengerId': 349, 'value': 'C'},
#  {'PassengerId': 351, 'value': 'B'},
#  {'PassengerId': 352, 'value': 'C'},
#  {'PassengerId': 353, 'value': 'C'},
#  {'PassengerId': 354, 'value': 'F'},
#  {'PassengerId': 357, 'value': 'F'},
#  {'PassengerId': 358, 'value': 'C'},
#  {'PassengerId': 359, 'value': 'F'},
#  {'PassengerId': 360, 'value': 'C'},
#  {'PassengerId': 361, 'value': 'C'},
#  {'PassengerId': 362, 'value': 'C'},
#  {'PassengerId': 363, 'value': 'F'},
#  {'PassengerId': 365, 'value': 'F'},
#  {'PassengerId': 366, 'value': 'C'},
#  {'PassengerId': 367, 'value': 'F'},
#  {'PassengerId': 368, 'value': 'C'},
#  {'PassengerId': 369, 'value': 'C'},
#  {'PassengerId': 370, 'value': 'B'},
#  {'PassengerId': 373, 'value': 'C'},
#  {'PassengerId': 375, 'value': 'C'},
#  {'PassengerId': 376, 'value': 'F'},
#  {'PassengerId': 377, 'value': 'B'},
#  {'PassengerId': 379, 'value': 'F'},
#  {'PassengerId': 380, 'value': 'C'},
#  {'PassengerId': 381, 'value': 'C'},
#  {'PassengerId': 382, 'value': 'F'},
#  {'PassengerId': 383, 'value': 'F'},
#  {'PassengerId': 384, 'value': 'B'},
#  {'PassengerId': 385, 'value': 'C'},
#  {'PassengerId': 386, 'value': 'F'},
#  {'PassengerId': 387, 'value': 'C'},
#  {'PassengerId': 388, 'value': 'C'},
#  {'PassengerId': 389, 'value': 'F'},
#  {'PassengerId': 392, 'value': 'F'},
#  {'PassengerId': 393, 'value': 'C'},
#  {'PassengerId': 394, 'value': 'F'},
#  {'PassengerId': 396, 'value': 'C'},
#  {'PassengerId': 398, 'value': 'F'},
#  {'PassengerId': 399, 'value': 'C'},
#  {'PassengerId': 401, 'value': 'C'},
#  {'PassengerId': 402, 'value': 'C'},
#  {'PassengerId': 403, 'value': 'B'},
#  {'PassengerId': 406, 'value': 'B'},
#  {'PassengerId': 408, 'value': 'C'},
#  {'PassengerId': 409, 'value': 'F'},
#  {'PassengerId': 410, 'value': 'C'},
#  {'PassengerId': 412, 'value': 'F'},
#  {'PassengerId': 413, 'value': 'F'},
#  {'PassengerId': 415, 'value': 'F'},
#  {'PassengerId': 416, 'value': 'F'},
#  {'PassengerId': 417, 'value': 'C'}]

# %%
# save predition to file
output = pd.DataFrame(filled_null_cabin_chars)
output.to_csv('filled_null_cabin_chars_test.csv', index=False)
