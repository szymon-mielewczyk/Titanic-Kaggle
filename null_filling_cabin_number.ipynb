# %%
import pandas as pd
import os
import torch
import numpy as np
import random
from sklearn.model_selection import cross_val_score
from sklearn import ensemble
import warnings
warnings.filterwarnings('ignore')

# %%
# fix seed for reproducibility
SEED = 0
torch.manual_seed(SEED)
random.seed(SEED)
np.random.seed(SEED)

# %%
# Preprocess and clean data
def clean_df(df, test=False):
    
    # Drop PassengerId and Name
    df.drop('PassengerId', axis='columns', inplace=True)
    df.drop('Name', axis='columns', inplace=True)

    # Cabin dictionary, char to int
    cabin_dict = {
    'A':0,
    'B':1,
    'C':2,
    'D':3,
    'E':4,
    'F':5,
    'G':6,
    'T':7
    }

    # Change cabin value just to char ids, ex.  B36 -> 1
    # Column for training data
    if not test:
        # Iterate by rows
        for c_i, cabin in enumerate(df['Cabin']):
            # Change only value with str datatype
            if not isinstance(cabin,str):
                continue
            # Iterate by row value
            for n_i ,char in enumerate(cabin):
                # Start iterating from last to first char
                index = -1 - n_i
                # If given char in cabin dictionary
                if cabin[index] in cabin_dict.keys():
                    # Cabin number
                    cabin_number = df['Cabin'][c_i][index+1:]
                    # If cabin number == cabin letter put 0
                    if cabin_number in cabin_dict.keys(): cabin_number = 0
                    # Change given row value to cabin number
                    df.loc[c_i, 'Cabin'] =   int(cabin_number)
                    break

    # Change ticket value just to numbers
    # Iterate by rows
    for t_i, ticket in enumerate(df['Ticket']):
        # If ticket value == LINE change to 0
        if ticket == 'LINE':
            df.loc[t_i, 'Ticket'] = 0
        # Iterate by row value
        for c_i ,char in enumerate(ticket):
            # Start iterating from last to first char
            index = -1 - c_i
            # If whitespace found 
            if ticket[index] == ' ':
                # Change value to numbers after whitespace
                df.loc[t_i, 'Ticket'] = df['Ticket'][t_i][index+1:]   
                break
        continue

        # Reset dataframe indexing
    df.reset_index()

    # Create column for each embarked
    df['Embarked_C'] = [1 if embarked == 'C' else 0 for embarked in df['Embarked']]
    df['Embarked_Q'] = [1 if embarked == 'Q' else 0 for embarked in df['Embarked']]
    df['Embarked_S'] = [1 if embarked == 'S' else 0 for embarked in df['Embarked']]
    
    # delete old embarked column
    df.drop('Embarked', axis='columns', inplace=True)

    # Sex dictionary, str to int
    sex_dict = {
        'male':0,
        'female':1
    }

    # Replace values in dataframe with dictionary
    df.replace({'Sex':sex_dict}, inplace=True)

    # Fill na values with mean
    df.fillna(
                {
                'Age': df['Age'].mean(),
                'Fare': df['Fare'].mean(),
                },
                inplace=True
                ) 

    # If training data save temporary column
    if not test:
        df_y = df['Cabin']
        df_y= (df_y).astype(float)
        # drop Cabin from dataframe
        df.drop('Cabin', axis='columns', inplace=True)
    
    # Drop rows with empty Ticket value
    df = df[df.Ticket != '']
    # Change Ticket datatype
    df['Ticket'] = (df['Ticket']).astype(float)

    # If training join Cabin column
    if not test:
        df = df.join(df_y)
        # Print cabin max and min values
        df_cabin_max = df['Cabin'].max()
        print('max',df['Cabin'].max(),'min',df['Cabin'].min())

    # Change dataframe values range from 0 to 1
    df=(df-df.min())/(df.max()-df.min())

    # If training return dataframe and max cabin value
    if not test:
        return df, df_cabin_max
    else:
        return df

# %%
# load data
DATA_PATH = 'data'
train_data_path = os.path.join(DATA_PATH,'test.csv')
train_df = pd.read_csv(train_data_path, sep=',')

# extract null values to predict
df_to_predict = train_df[train_df.isnull().any(axis=1)]
df_to_predict.reset_index(inplace=True)

# save list of row indexes for prediction
null_indexes = df_to_predict['index']
# drop index and Cabin column
df_to_predict.drop('index', axis='columns', inplace=True)
df_to_predict.drop('Cabin', axis='columns', inplace=True)
# preprocess data for prediction
df_to_predict = clean_df(df_to_predict, test=True)
# drop null values
train_df = train_df.dropna()
train_df.reset_index(inplace=True)
# drop index
train_df.drop('index', axis='columns', inplace=True)
# preprocess training data
train_df, df_cabin_max = clean_df(train_df)
# change df to np
train_set = train_df.to_numpy()
data_to_predict = df_to_predict.to_numpy()

#split data
print(len(train_set))
train_set, val_set = torch.utils.data.random_split(train_set, [70, 17])

# change np to array | to avoid slice errors
train_set = np.array(train_set)
val_set = np.array(val_set)
X_train,y_train = train_set[:,:-1],train_set[:,-1]
X_val,y_val = val_set[:,:-1],val_set[:,-1]
# Out:
# max 132.0 min 0.0
# 87

# %%
# set params
params = {
    "n_estimators": 500,
    "max_depth": 4,
    "min_samples_split": 5,
    "learning_rate": 0.01,
    "loss": "squared_error",
}

# create model
reg = ensemble.GradientBoostingRegressor(**params)

# train model
reg.fit(X_train, y_train)

# score model
reg.score(X_val, y_val)

# cross validation
scores = cross_val_score(reg, X_train, y_train, cv = 4)
scores
# Out:
# array([-0.01935327, -0.83645562,  0.09830709, -0.50642099])

# %%
# predict cabin number
pred = reg.predict(data_to_predict)
# create list for predictions
filled_null_cabin_numbers = []
# Create a list of PassengerId: prediction
for index, value in zip(null_indexes,pred):
    filled_null_cabin_numbers.append({
        'PassengerId':index,
        'value':int(round(value * df_cabin_max,0))
    })
filled_null_cabin_numbers
# Out:
# [{'PassengerId': 0, 'value': 23},
#  {'PassengerId': 1, 'value': 43},
#  {'PassengerId': 2, 'value': 40},
#  {'PassengerId': 3, 'value': 22},
#  {'PassengerId': 4, 'value': 27},
#  {'PassengerId': 5, 'value': 15},
#  {'PassengerId': 6, 'value': 23},
#  {'PassengerId': 7, 'value': 26},
#  {'PassengerId': 8, 'value': 33},
#  {'PassengerId': 9, 'value': 26},
#  {'PassengerId': 10, 'value': 22},
#  {'PassengerId': 11, 'value': 42},
#  {'PassengerId': 13, 'value': 44},
#  {'PassengerId': 15, 'value': 30},
#  {'PassengerId': 16, 'value': 21},
#  {'PassengerId': 17, 'value': 33},
#  {'PassengerId': 18, 'value': 26},
#  {'PassengerId': 19, 'value': 55},
#  {'PassengerId': 20, 'value': 62},
#  {'PassengerId': 21, 'value': 36},
#  {'PassengerId': 22, 'value': 12},
#  {'PassengerId': 23, 'value': 44},
#  {'PassengerId': 25, 'value': 48},
#  {'PassengerId': 27, 'value': 33},
#  {'PassengerId': 29, 'value': 47},
#  {'PassengerId': 30, 'value': 42},
#  {'PassengerId': 31, 'value': 37},
#  {'PassengerId': 32, 'value': 13},
#  {'PassengerId': 33, 'value': 14},
#  {'PassengerId': 35, 'value': 33},
#  {'PassengerId': 36, 'value': 22},
#  {'PassengerId': 37, 'value': 23},
#  {'PassengerId': 38, 'value': 23},
#  {'PassengerId': 39, 'value': 104},
#  {'PassengerId': 40, 'value': 28},
#  {'PassengerId': 41, 'value': 20},
#  {'PassengerId': 42, 'value': 52},
#  {'PassengerId': 43, 'value': 20},
#  {'PassengerId': 45, 'value': 28},
#  {'PassengerId': 47, 'value': 22},
#  {'PassengerId': 49, 'value': 16},
#  {'PassengerId': 51, 'value': 26},
#  {'PassengerId': 52, 'value': 28},
#  {'PassengerId': 54, 'value': 26},
#  {'PassengerId': 55, 'value': 52},
#  {'PassengerId': 56, 'value': 22},
#  {'PassengerId': 58, 'value': 21},
#  {'PassengerId': 60, 'value': 23},
#  {'PassengerId': 61, 'value': 21},
#  {'PassengerId': 62, 'value': 23},
#  {'PassengerId': 63, 'value': 25},
#  {'PassengerId': 65, 'value': 16},
#  {'PassengerId': 66, 'value': 25},
#  {'PassengerId': 67, 'value': 52},
#  {'PassengerId': 70, 'value': 26},
#  {'PassengerId': 71, 'value': 23},
#  {'PassengerId': 72, 'value': 26},
#  {'PassengerId': 76, 'value': 22},
#  {'PassengerId': 78, 'value': 21},
#  {'PassengerId': 79, 'value': 26},
#  {'PassengerId': 80, 'value': 23},
#  {'PassengerId': 82, 'value': 42},
#  {'PassengerId': 83, 'value': 22},
#  {'PassengerId': 84, 'value': 21},
#  {'PassengerId': 85, 'value': 24},
#  {'PassengerId': 86, 'value': 22},
#  {'PassengerId': 87, 'value': 19},
#  {'PassengerId': 88, 'value': 22},
#  {'PassengerId': 89, 'value': 16},
#  {'PassengerId': 90, 'value': 23},
#  {'PassengerId': 91, 'value': 22},
#  {'PassengerId': 93, 'value': 22},
#  {'PassengerId': 94, 'value': 26},
#  {'PassengerId': 95, 'value': 23},
#  {'PassengerId': 97, 'value': 27},
#  {'PassengerId': 98, 'value': 23},
#  {'PassengerId': 99, 'value': 17},
#  {'PassengerId': 101, 'value': 16},
#  {'PassengerId': 102, 'value': 22},
#  {'PassengerId': 103, 'value': 22},
#  {'PassengerId': 104, 'value': 30},
#  {'PassengerId': 105, 'value': 14},
#  {'PassengerId': 106, 'value': 26},
#  {'PassengerId': 107, 'value': 22},
#  {'PassengerId': 108, 'value': 18},
#  {'PassengerId': 110, 'value': 39},
#  {'PassengerId': 111, 'value': 22},
#  {'PassengerId': 113, 'value': 25},
#  {'PassengerId': 115, 'value': 31},
#  {'PassengerId': 116, 'value': 27},
#  {'PassengerId': 119, 'value': 16},
#  {'PassengerId': 120, 'value': 19},
#  {'PassengerId': 121, 'value': 22},
#  {'PassengerId': 123, 'value': 22},
#  {'PassengerId': 124, 'value': 22},
#  {'PassengerId': 125, 'value': 23},
#  {'PassengerId': 126, 'value': 23},
#  {'PassengerId': 127, 'value': 38},
#  {'PassengerId': 128, 'value': 45},
#  {'PassengerId': 129, 'value': 24},
#  {'PassengerId': 130, 'value': 24},
#  {'PassengerId': 132, 'value': 14},
#  {'PassengerId': 133, 'value': 27},
#  {'PassengerId': 134, 'value': 45},
#  {'PassengerId': 135, 'value': 24},
#  {'PassengerId': 136, 'value': 27},
#  {'PassengerId': 137, 'value': 20},
#  {'PassengerId': 138, 'value': 23},
#  {'PassengerId': 139, 'value': 49},
#  {'PassengerId': 140, 'value': 30},
#  {'PassengerId': 141, 'value': 66},
#  {'PassengerId': 143, 'value': 16},
#  {'PassengerId': 144, 'value': 41},
#  {'PassengerId': 145, 'value': 30},
#  {'PassengerId': 146, 'value': 104},
#  {'PassengerId': 147, 'value': 20},
#  {'PassengerId': 148, 'value': 20},
#  {'PassengerId': 149, 'value': 17},
#  {'PassengerId': 151, 'value': 23},
#  {'PassengerId': 152, 'value': 41},
#  {'PassengerId': 153, 'value': 21},
#  {'PassengerId': 154, 'value': 31},
#  {'PassengerId': 155, 'value': 22},
#  {'PassengerId': 157, 'value': 23},
#  {'PassengerId': 159, 'value': 24},
#  {'PassengerId': 160, 'value': 22},
#  {'PassengerId': 161, 'value': 23},
#  {'PassengerId': 162, 'value': 19},
#  {'PassengerId': 163, 'value': 22},
#  {'PassengerId': 164, 'value': 47},
#  {'PassengerId': 165, 'value': 18},
#  {'PassengerId': 167, 'value': 31},
#  {'PassengerId': 168, 'value': 24},
#  {'PassengerId': 169, 'value': 19},
#  {'PassengerId': 170, 'value': 20},
#  {'PassengerId': 171, 'value': 27},
#  {'PassengerId': 172, 'value': 24},
#  {'PassengerId': 173, 'value': 27},
#  {'PassengerId': 174, 'value': 32},
#  {'PassengerId': 175, 'value': 17},
#  {'PassengerId': 176, 'value': 25},
#  {'PassengerId': 180, 'value': 21},
#  {'PassengerId': 183, 'value': 26},
#  {'PassengerId': 185, 'value': 39},
#  {'PassengerId': 186, 'value': 23},
#  {'PassengerId': 187, 'value': 27},
#  {'PassengerId': 188, 'value': 103},
#  {'PassengerId': 189, 'value': 51},
#  {'PassengerId': 190, 'value': 16},
#  {'PassengerId': 191, 'value': 15},
#  {'PassengerId': 192, 'value': 14},
#  {'PassengerId': 193, 'value': 40},
#  {'PassengerId': 194, 'value': 14},
#  {'PassengerId': 195, 'value': 22},
#  {'PassengerId': 197, 'value': 23},
#  {'PassengerId': 198, 'value': 22},
#  {'PassengerId': 199, 'value': 19},
#  {'PassengerId': 200, 'value': 22},
#  {'PassengerId': 201, 'value': 17},
#  {'PassengerId': 203, 'value': 17},
#  {'PassengerId': 204, 'value': 22},
#  {'PassengerId': 205, 'value': 24},
#  {'PassengerId': 206, 'value': 25},
#  {'PassengerId': 207, 'value': 22},
#  {'PassengerId': 209, 'value': 23},
#  {'PassengerId': 210, 'value': 15},
#  {'PassengerId': 211, 'value': 26},
#  {'PassengerId': 212, 'value': 54},
#  {'PassengerId': 213, 'value': 44},
#  {'PassengerId': 214, 'value': 22},
#  {'PassengerId': 216, 'value': 22},
#  {'PassengerId': 217, 'value': 51},
#  {'PassengerId': 219, 'value': 18},
#  {'PassengerId': 220, 'value': 26},
#  {'PassengerId': 221, 'value': 23},
#  {'PassengerId': 223, 'value': 23},
#  {'PassengerId': 224, 'value': 50},
#  {'PassengerId': 225, 'value': 22},
#  {'PassengerId': 226, 'value': 24},
#  {'PassengerId': 227, 'value': 22},
#  {'PassengerId': 228, 'value': 45},
#  {'PassengerId': 229, 'value': 20},
#  {'PassengerId': 230, 'value': 27},
#  {'PassengerId': 231, 'value': 27},
#  {'PassengerId': 232, 'value': 27},
#  {'PassengerId': 233, 'value': 22},
#  {'PassengerId': 235, 'value': 23},
#  {'PassengerId': 237, 'value': 33},
#  {'PassengerId': 238, 'value': 21},
#  {'PassengerId': 240, 'value': 33},
#  {'PassengerId': 241, 'value': 32},
#  {'PassengerId': 243, 'value': 18},
#  {'PassengerId': 244, 'value': 14},
#  {'PassengerId': 246, 'value': 23},
#  {'PassengerId': 247, 'value': 41},
#  {'PassengerId': 248, 'value': 16},
#  {'PassengerId': 249, 'value': 24},
#  {'PassengerId': 250, 'value': 19},
#  {'PassengerId': 251, 'value': 27},
#  {'PassengerId': 253, 'value': 20},
#  {'PassengerId': 254, 'value': 24},
#  {'PassengerId': 255, 'value': 21},
#  {'PassengerId': 256, 'value': 25},
#  {'PassengerId': 257, 'value': 22},
#  {'PassengerId': 258, 'value': 22},
#  {'PassengerId': 259, 'value': 23},
#  {'PassengerId': 260, 'value': 21},
#  {'PassengerId': 261, 'value': 23},
#  {'PassengerId': 262, 'value': 17},
#  {'PassengerId': 263, 'value': 18},
#  {'PassengerId': 264, 'value': 27},
#  {'PassengerId': 265, 'value': 22},
#  {'PassengerId': 266, 'value': 45},
#  {'PassengerId': 267, 'value': 21},
#  {'PassengerId': 268, 'value': 18},
#  {'PassengerId': 269, 'value': 23},
#  {'PassengerId': 271, 'value': 22},
#  {'PassengerId': 273, 'value': 21},
#  {'PassengerId': 274, 'value': 27},
#  {'PassengerId': 275, 'value': 23},
#  {'PassengerId': 276, 'value': 20},
#  {'PassengerId': 277, 'value': 42},
#  {'PassengerId': 278, 'value': 17},
#  {'PassengerId': 279, 'value': 22},
#  {'PassengerId': 280, 'value': 23},
#  {'PassengerId': 281, 'value': 21},
#  {'PassengerId': 282, 'value': 22},
#  {'PassengerId': 283, 'value': 28},
#  {'PassengerId': 284, 'value': 21},
#  {'PassengerId': 285, 'value': 20},
#  {'PassengerId': 286, 'value': 26},
#  {'PassengerId': 288, 'value': 27},
#  {'PassengerId': 289, 'value': 18},
#  {'PassengerId': 290, 'value': 14},
#  {'PassengerId': 291, 'value': 23},
#  {'PassengerId': 292, 'value': 27},
#  {'PassengerId': 294, 'value': 22},
#  {'PassengerId': 295, 'value': 22},
#  {'PassengerId': 296, 'value': 25},
#  {'PassengerId': 297, 'value': 47},
#  {'PassengerId': 298, 'value': 58},
#  {'PassengerId': 299, 'value': 22},
#  {'PassengerId': 300, 'value': 24},
#  {'PassengerId': 301, 'value': 20},
#  {'PassengerId': 302, 'value': 42},
#  {'PassengerId': 303, 'value': 24},
#  {'PassengerId': 304, 'value': 22},
#  {'PassengerId': 307, 'value': 18},
#  {'PassengerId': 309, 'value': 38},
#  {'PassengerId': 310, 'value': 23},
#  {'PassengerId': 311, 'value': 33},
#  {'PassengerId': 312, 'value': 20},
#  {'PassengerId': 313, 'value': 22},
#  {'PassengerId': 315, 'value': 32},
#  {'PassengerId': 317, 'value': 22},
#  {'PassengerId': 318, 'value': 22},
#  {'PassengerId': 319, 'value': 37},
#  {'PassengerId': 320, 'value': 22},
#  {'PassengerId': 323, 'value': 19},
#  {'PassengerId': 324, 'value': 54},
#  {'PassengerId': 325, 'value': 28},
#  {'PassengerId': 327, 'value': 63},
#  {'PassengerId': 328, 'value': 16},
#  {'PassengerId': 329, 'value': 21},
#  {'PassengerId': 330, 'value': 45},
#  {'PassengerId': 332, 'value': 27},
#  {'PassengerId': 333, 'value': 31},
#  {'PassengerId': 334, 'value': 22},
#  {'PassengerId': 336, 'value': 21},
#  {'PassengerId': 337, 'value': 30},
#  {'PassengerId': 338, 'value': 15},
#  {'PassengerId': 339, 'value': 27},
#  {'PassengerId': 340, 'value': 22},
#  {'PassengerId': 341, 'value': 24},
#  {'PassengerId': 342, 'value': 105},
#  {'PassengerId': 344, 'value': 18},
#  {'PassengerId': 345, 'value': 23},
#  {'PassengerId': 346, 'value': 20},
#  {'PassengerId': 347, 'value': 30},
#  {'PassengerId': 348, 'value': 21},
#  {'PassengerId': 349, 'value': 17},
#  {'PassengerId': 351, 'value': 22},
#  {'PassengerId': 352, 'value': 54},
#  {'PassengerId': 353, 'value': 83},
#  {'PassengerId': 354, 'value': 14},
#  {'PassengerId': 357, 'value': 18},
#  {'PassengerId': 358, 'value': 22},
#  {'PassengerId': 359, 'value': 21},
#  {'PassengerId': 360, 'value': 53},
#  {'PassengerId': 361, 'value': 32},
#  {'PassengerId': 362, 'value': 17},
#  {'PassengerId': 363, 'value': 22},
#  {'PassengerId': 365, 'value': 105},
#  {'PassengerId': 366, 'value': 24},
#  {'PassengerId': 367, 'value': 27},
#  {'PassengerId': 368, 'value': 72},
#  {'PassengerId': 369, 'value': 27},
#  {'PassengerId': 370, 'value': 22},
#  {'PassengerId': 373, 'value': 45},
#  {'PassengerId': 375, 'value': 57},
#  {'PassengerId': 376, 'value': 29},
#  {'PassengerId': 377, 'value': 22},
#  {'PassengerId': 379, 'value': 31},
#  {'PassengerId': 380, 'value': 22},
#  {'PassengerId': 381, 'value': 22},
#  {'PassengerId': 382, 'value': 21},
#  {'PassengerId': 383, 'value': 23},
#  {'PassengerId': 384, 'value': 20},
#  {'PassengerId': 385, 'value': 45},
#  {'PassengerId': 386, 'value': 24},
#  {'PassengerId': 387, 'value': 41},
#  {'PassengerId': 388, 'value': 26},
#  {'PassengerId': 389, 'value': 21},
#  {'PassengerId': 392, 'value': 17},
#  {'PassengerId': 393, 'value': 51},
#  {'PassengerId': 394, 'value': 29},
#  {'PassengerId': 396, 'value': 26},
#  {'PassengerId': 398, 'value': 23},
#  {'PassengerId': 399, 'value': 27},
#  {'PassengerId': 401, 'value': 16},
#  {'PassengerId': 402, 'value': 60},
#  {'PassengerId': 403, 'value': 32},
#  {'PassengerId': 406, 'value': 22},
#  {'PassengerId': 408, 'value': 22},
#  {'PassengerId': 409, 'value': 21},
#  {'PassengerId': 410, 'value': 22},
#  {'PassengerId': 412, 'value': 22},
#  {'PassengerId': 413, 'value': 18},
#  {'PassengerId': 415, 'value': 31},
#  {'PassengerId': 416, 'value': 22},
#  {'PassengerId': 417, 'value': 21}]

# %%
# save predition to file
output = pd.DataFrame(filled_null_cabin_numbers)
output.to_csv('filled_null_cabin_numbers_test.csv', index=False)
